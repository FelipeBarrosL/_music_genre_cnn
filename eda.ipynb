# %%
import torchaudio
from plot_audio import plot_waveform, plot_specgram
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path

# %%
#To verify if there is an audio backend installed, if not run pip install soundfile 
torchaudio.info
# Out:
# <function torchaudio.backend.soundfile_backend.info(filepath: str, format: Optional[str] = None) -> torchaudio.backend.common.AudioMetaData>

# %%
#.wav file import for eda 
wav_file = './Data/set_a/artifact__201105040918.wav'
data_waveform, sample_rate = torchaudio.load(wav_file)
print('Audio Sample Rate =', sr, "\nFile size", data_waveform.size())
# Out:
# Audio Sample Rate = 44100
# File size torch.Size([1, 396900])

# %%
#Plotting audio waveform
plot_waveform(waveform=data_waveform, sample_rate=sample_rate)

# %%
#Plotting audio signal spectrogram

spectrogram = torchaudio.transforms.Spectrogram()(data_waveform)
print(spectrogram.size())
plot_specgram(waveform=data_waveform, sample_rate=sample_rate)
# Out:
# torch.Size([1, 201, 1985])
